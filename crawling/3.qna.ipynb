# %%
ㅌ

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

def setup_driver():
    chrome_options = Options()
    chrome_options.add_argument('--headless')  # 필요하지 않다면 주석 처리
    chrome_options.add_argument('--no-sandbox')
    chrome_options.add_argument('--disable-dev-shm-usage')
    
    driver = webdriver.Chrome(options=chrome_options)
    return driver

def crawl_faq():
    driver = setup_driver()
    try:
        url = "https://www.129.go.kr/faq/faq05.do?searchConsultingKeyword=0"
        driver.get(url)
        
        # FAQ ID를 가진 행들 찾기
        faq_rows = driver.find_elements(By.CSS_SELECTOR, 'tr[id^="faq"]')
        results = []
        for faq_row in faq_rows:
            try:
                # FAQ ID 다음 행(== $0)에서 질문과 답변 찾기
                faq_id = faq_row.get_attribute('id')
                next_row = driver.find_element(By.XPATH, f"//tr[@id='{faq_id}']/following-sibling::tr[1]")
                
                # 질문과 답변 추출
                question_div = next_row.find_element(By.XPATH, './/div[contains(@class, "q")]')
                answer_div = next_row.find_element(By.XPATH, './/div[contains(@class, "a")]')
                
                question = question_div.text if question_div else ""
                answer = answer_div.text if answer_div else ""
                
                if question and answer:
                    results.append({
                        'faq_id': faq_id,
                        'question': question,
                        'answer': answer
                    })
                    
            except Exception as e:
                print(f"FAQ ID {faq_id} 처리 중 오류 발생: {e}")
                continue
                
        return results
        
    except Exception as e:
        print(f"크롤링 중 오류 발생: {e}")
        return None
        
    finally:
        driver.quit()

def save_to_file(results, filename='faq_results.txt'):
    if not results:
        return
        
    with open(filename, 'w', encoding='utf-8') as f:
        for i, item in enumerate(results, 1):
            f.write(f"\n[FAQ {item['faq_id']}]\n")
            f.write("질문:\n")
            f.write(f"{item['question']}\n\n")
            f.write("답변:\n")
            f.write(f"{item['answer']}\n")
            f.write("\n" + "="*50 + "\n")

def save_to_csv(results, filename='faq_results.csv'):
    import csv
    if not results:
        return
        
    with open(filename, 'w', encoding='utf-8', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['FAQ ID', '질문', '답변'])
        for item in results:
            writer.writerow([item['faq_id'], item['question'], item['answer']])

if __name__ == "__main__":
    results = crawl_faq()
    if results:
        # 결과 출력
        for item in results:
            print(f"\n[FAQ {item['faq_id']}]")
            print("질문:")
            print(item['question'])
            print("\n답변:")
            print(item['answer'])
            print("="*50)
        
        # 파일로 저장
        save_to_file(results)
        save_to_csv(results)
# Out:
# faq14999
# FAQ ID faq14999 처리 중 오류 발생: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//div[contains(@class, "q")]"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x000000010532fb08 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000105328358 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x0000000104d904b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104dd4898 cxxbridge1$string$len + 368748
# 4   chromedriver                        0x0000000104dcaa10 cxxbridge1$string$len + 328164
# 5   chromedriver                        0x0000000104e0e0fc cxxbridge1$string$len + 604368
# 6   chromedriver                        0x0000000104dc90b0 cxxbridge1$string$len + 321668
# ...
