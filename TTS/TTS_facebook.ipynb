# %%
from transformers import VitsModel, AutoTokenizer
import torch

model = VitsModel.from_pretrained("facebook/mms-tts-kor")
tokenizer = AutoTokenizer.from_pretrained("facebook/mms-tts-kor")

text = "안녕하세요 반가워요 잘있어요 다시만나요"
inputs = tokenizer(text, return_tensors="pt")

# speaker embeddings 설정 (모델의 speaker embedding 차원과 일치해야 함)
batch_size = inputs.input_ids.shape[0]
speaker_embeddings = torch.randn(batch_size, model.config.speaker_embedding_size)

with torch.no_grad():
    output = model(
        **inputs,
        speaker_embeddings=speaker_embeddings
    ).waveform
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 15
#      12 speaker_embeddings = torch.randn(batch_size, model.config.speaker_embedding_size)
#      14 with torch.no_grad():
# ---> 15     output = model(
#      16         **inputs,
#      17         speaker_embeddings=speaker_embeddings
#      18     ).waveform
#
# File ~/.pyenv/versions/3.10.9/envs/wav2vec-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.9/envs/wav2vec-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
# ...

# %%
from IPython.display import Audio

Audio(output, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
